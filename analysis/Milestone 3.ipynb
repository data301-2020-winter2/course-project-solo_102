# %% [markdown]
# # Milestone 3

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Task 3 - Process Data for Tableau

# %%
from Scripts.project_functions import load_and_process
dogs = load_and_process('../data/raw/ShelterDogs.xls')
dogs
# Out:
#          ID    age     sex                                   breed date_found  \
# 0     23807   0.25  female                             Unknown Mix 2019-12-10
# 1       533   0.17  female                             Unknown Mix 2019-12-01
# 2     23793   4.00    male                             Unknown Mix 2019-12-08
# 3     23795   1.00    male                             Unknown Mix 2019-12-08
# 4     23806   2.00  female                      French Bulldog Mix 2019-12-10
# ...     ...    ...     ...                                     ...        ...
# 2767    427  13.75    male                 German Shepherd Dog Mix 2006-06-01
# 2768    109  13.33  female             German Pointer, Pointer Mix 2007-01-15
# 2769    110  13.75    male                                Pumi Mix 2007-01-15
# 2770    389  14.25  female  German Pointer, Greyhound, Pointer Mix 2006-08-01
# 2771    362  14.75  female                  Labrador Retriever Mix 2006-05-01
#
#      adoptable_from date_posted            color coat_length    size neutered  \
# 0        2019-12-11  2019-12-11              red       short   small       no
# 1        2019-12-01  2019-12-09  black and white       short   small       no
# 2        2019-12-23  2019-12-08      saddle back       short  medium       no
# 3        2019-12-23  2019-12-08     yellow-brown      medium  medium       no
# 4        2019-12-11  2019-12-11            black       short   small       no
# ...             ...         ...              ...         ...     ...      ...
# 2767     2006-06-01  2006-11-29              red       short  medium      yes
# 2768     2007-01-15  2007-03-16  black and white       short  medium      NaN
# 2769     2007-01-15  2007-03-17          striped      medium  medium      NaN
# 2770     2006-08-01  2006-08-20  black and white       short  medium      yes
# 2771     2006-05-01  2006-06-28          apricot      medium  medium      yes
#
#       month_found  year_found
# 0              12        2019
# 1              12        2019
# 2              12        2019
# 3              12        2019
# 4              12        2019
# ...           ...         ...
# 2767            6        2006
# 2768            1        2007
# 2769            1        2007
# 2770            8        2006
# 2771            5        2006
#
# [2772 rows x 13 columns]

# %%
dogs.to_csv('../data/processed/ShelterDogsProcessed.xls')
